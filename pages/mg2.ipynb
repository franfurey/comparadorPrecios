# %%
# FUREY 
# https://www.furey.com.ar/

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import credentials
import scrapy

def scrape_mg(login_url, products_url):
    session = requests.Session()

    payload = {'email': credentials.email_mg, 'password': credentials.password_mg}

    # Enviar la solicitud POST para iniciar sesión
    response = session.post(login_url, data=payload)

    # Verificar si el inicio de sesión fue exitoso
    if response.status_code == 200:
        print('Inicio de sesión exitoso')
    else:
        print('Inicio de sesión fallido')
        exit()

    # Crear un DataFrame vacío
    df = pd.DataFrame(columns=['name', 'price', 'brand', 'codigo de barra'])

    url = products_url

    while True:
        # Obtener el código HTML de la página web
        page = session.get(url)

        # Crear un objeto BeautifulSoup para analizar el código HTML
        soup = BeautifulSoup(page.content, 'html.parser')

        # Buscar todos los elementos con la clase 'product'
        products = soup.find_all('a', class_='copete')
        print(len(products))
        # Iterar sobre cada producto
        for product in products:
            # Buscar el enlace del producto
            link = "https://drogueriamg.com/" + product['href']
            price1 = product.find('strong')
            print('price1',price1)

            # name1 = product.text.strip()

            # Acceder a la página del producto
            product_page = session.get(link)
            product_soup = BeautifulSoup(product_page.content, 'html.parser')

            name = product_soup.find('h3').text
            print('name2', name)
            price = product_soup.find('div',class_='col-ofertas').text
            print('price', price)

            # Agregar la información al DataFrame
            df.loc[len(df)] = [name, price]
    # Guardar el DataFrame en un archivo CSV
        df.to_csv('../df/productos_furey.csv', index=False)
        print('Archivo guardado con exito')
        return True

scrape_mg('https://drogueriamg.com/index.php','https://drogueriamg.com/drogueria-mg-productos.php')
# Out:
# Inicio de sesión exitoso
# 50
# price1 None
# name2 ACEITE DE ALMENDRAS X 40CC TABLADA
# price
#
#
#
#
#
#
# Agregar al carro
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mb/tcvp4z490sz6dt5nlf1qwh580000gn/T/ipykernel_45841/3561952736.py in <module>
#      65         return True
#      66
# ---> 67 scrape_mg('https://drogueriamg.com/index.php','https://drogueriamg.com/drogueria-mg-productos.php')
#
# /var/folders/mb/tcvp4z490sz6dt5nlf1qwh580000gn/T/ipykernel_45841/3561952736.py in scrape_mg(login_url, products_url)
#      59
#      60             # Agregar la información al DataFrame
# ---> 61             df.loc[len(df)] = [name, price]
#      62     # Guardar el DataFrame en un archivo CSV
#      63         df.to_csv('../df/productos_furey.csv', index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1683
#    1684             if missing:
# -> 1685                 self._setitem_with_indexer_missing(indexer, value)
#    1686                 return
#    1687
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2001                     # must have conforming columns
#    2002                     if len(value) != len(self.obj.columns):
# -> 2003                         raise ValueError("cannot set a row with mismatched columns")
#    2004
#    2005                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %%
import scrapy

class PrecioSpider(scrapy.Spider):
    name = "precio"

    start_urls = [
        'https://drogueriamg.com/drogueria-mg-productos.php',
    ]

    def parse(self, response):
        precio = response.css('.precio-detalle strong::text').get()
        yield {'precio': precio}

# %%
session = requests.Session()
login_url = 'https://drogueriamg.com/index.php'


payload = {'email': credentials.email_mg, 'password': credentials.password_mg}

    # Enviar la solicitud POST para iniciar sesión
response = session.post(login_url, data=payload)

    # Verificar si el inicio de sesión fue exitoso
if response.status_code == 200:
    print('Inicio de sesión exitoso')
else:
    print('Inicio de sesión fallido')
    exit()

import scrapy

class PrecioSpider(scrapy.Spider):
    name = "precio"

    start_urls = [
        'https://drogueriamg.com/drogueria-mg-productos.php',
    ]

    def parse(self, response):
        for precio in response.css('.listado-productos a strong::text').getall():
            print('Precio',precio)
        yield {'precio': precio}
# Out:
# Inicio de sesión exitoso

# %%
# FUREY 
# https://www.furey.com.ar/

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import credentials
import scrapy

def scrape_mg(login_url, products_url):
    session = requests.Session()

    payload = {'email': credentials.email_mg, 'password': credentials.password_mg}

    # Enviar la solicitud POST para iniciar sesión
    response = session.post(login_url, data=payload)

    # Verificar si el inicio de sesión fue exitoso
    if response.status_code == 200:
        print('Inicio de sesión exitoso')
    else:
        print('Inicio de sesión fallido')
        exit()

    # Crear un DataFrame vacío
    df = pd.DataFrame(columns=['name', 'price', 'brand', 'codigo de barra'])

    url = products_url

    while True:
        # Obtener el código HTML de la página web
        page = session.get(url)

        # Crear un objeto BeautifulSoup para analizar el código HTML
        soup = BeautifulSoup(page.content, 'html.parser')

        # Buscar todos los elementos con la clase 'product'
        products = soup.find_all('a', class_='copete')
        print(len(products))
        # Iterar sobre cada producto
        for product in products:
            # Buscar el enlace del producto
            link = "https://drogueriamg.com/" + product['href']
            price1 = product.find('strong')
            print('price1',price1)

            # name1 = product.text.strip()

            # Acceder a la página del producto
            product_page = session.get(link)
            product_soup = BeautifulSoup(product_page.content, 'html.parser')
            try:
                precio_row = product_soup.find('p', class_='precio-detalle')
                precio = precio_row.find_next_sibling('strong').text
            # Buscar el elemento siguiente a la fila de la marca, el cual contiene el valor de la marca
                print('precio try',precio)
            except AttributeError:
                precio = None
                print('precio_except',precio)
        return True

scrape_mg('https://drogueriamg.com/index.php','https://drogueriamg.com/drogueria-mg-productos.php')
# Out:
# Inicio de sesión exitoso
# 50
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# price1 None
# precio_except None
# True

# %%
# FUREY 
# https://www.furey.com.ar/

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import credentials
import scrapy

def scrape_mg(url):
    session = requests.Session()

    payload = {'email': credentials.email_mg, 'password': credentials.password_mg}

    # Enviar la solicitud POST para iniciar sesión
    response = session.post(url, data=payload)

    # Verificar si el inicio de sesión fue exitoso
    if response.status_code == 200:
        print('Inicio de sesión exitoso')
    else:
        print('Inicio de sesión fallido')
        exit()


    new_url = 'https://drogueriamg.com/drogueria-mg-productos.php'
        # Obtener el código HTML de la página web
    page = session.get(new_url)

        # Crear un objeto BeautifulSoup para analizar el código HTML
    soup = BeautifulSoup(page.content, 'html.parser')

    catalogo = soup.find('body')
    print(catalogo)

    



scrape_mg('https://drogueriamg.com/index.php')
# Out:
# Inicio de sesión exitoso
# <body>
# <script language="javascript">
# function accionCarroMedio(_id, _cantidad, _comentario, _accion){
#
# 	if(_accion=='del'){
# 		if(!confirm('Seguro desea eliminar items?'))
# 			return false;
# 	}
# 	/*ACTUALIZO CARRO PEDIDOS*/
# 	jQuery.get("inc-carro-medio.php", { id: _id, cantidad: _cantidad, comentario: _comentario, actions: _accion},
# 	function(data){
# 		document.getElementById("carro-columna-detalle").innerHTML = data;
#
# 	});
# 	/*ACTUALIZO EL CONTADOR DE CARRO DEL TOP*/
# 	jQuery.get("inc-ver_carro.php",
# 	function(data){
# 		document.getElementById("ver_carro").innerHTML = data;
# 	});
# 	/*ACTUALIZO EL CARRO DE LA DERECHA*/
# 	/*jQuery.get("inc-carro.php", { id: _id, cantidad: _cantidad, actions: _accion},
# 	function(data){
# 		document.getElementById("contenido-carro").innerHTML = data;
# 	});
# 	*/
# 	return false;
# }
#
# function accionCarro(_id, _cantidad, _comentario, _accion){
#
#
# 	if(_accion=='del'){
# 		if(!confirm('Seguro desea eliminar items?'))
# 			return false;
# 	}
# 	//document.getElementById('contenido-carro').style.display = 'none';
# 	//document.getElementById('ajax-loader').style.display = 'block';
#
# 	jQuery.get("inc-carro.php", { id: _id, cantidad: _cantidad, comentario: _comentario, actions: _accion},
# 	function(data)
#     {
# 		//console.log(data);
#         document.getElementById("contenido-carro").innerHTML = data;
# 	});
# 	//document.getElementById('contenido-carro').style.display = 'block';
# 	//document.getElementById('ajax-loader').style.display = 'none';
# 	if(_accion=='add')
# 	document.getElementById('cc_'+_id).value = 1;
#
# 	jQuery.get("inc-ver_carro.php",
# 	function(data){
# 		document.getElementById("ver_carro").innerHTML = data;
# 	});
#
#
# 	return false;
# }
#
#
#
# function actualizar(){
# 	var _max = document.forms['form1'].maximo.value;
#
# 	for(var _x=0; _x<_max; _x++){
# 		_idU = document.getElementById('id_carro_'+_x).value;
# 		_cant = document.getElementById('cantidad_'+_x).value;
# 		_comentario = document.getElementById('comentario_'+_x).value;
# 		accionCarro(_idU, _cant, _comentario, 'edit');
# 	}
# 	return false;
# }
#
# function actualizarMedio(){
# 	var _max = document.forms['form1'].maximo.value;
#
# 	for(var _x=0; _x<_max; _x++){
# 		_idU = document.getElementById('id_carro_'+_x).value;
# 		_cant = document.getElementById('cantidad_'+_x).value;
# 		_coment = document.getElementById('comentario_'+_x).value;
# 		accionCarroMedio(_idU, _cant, _coment ,'edit');
# 	}
# 	return false;
# }
#
#
# function comprar(_this){
# 	_cliente = document.getElementById('clientes_id').value;
# 	if(_cliente==''){
# 		var cad = 'Error \n';
# 		cad += '---------------------------------------------\n';
# 		cad += 'Debe ser usuario registrado en nuestro sistema para poder realizar una compra\n';
# 		cad += '---------------------------------------------';
# 		alert(cad);
# 		return false;
# 	}else{
# 		if(submitForm(_this)){
# 			//document.getElementById('msg-ok').style.display = 'block';
# 			return true;
# 		}else
# 			return false;
# 	}
# }
#
# function cliente_comprar(_this){
# 	_cliente = document.getElementById('clientes_id').value;
# 	if(_cliente==''){
# 		var cad = 'Error \n';
# 		cad += '---------------------------------------------\n';
# 		cad += 'Debe ser usuario registrado en nuestro sistema para poder realizar una compra\n';
# 		cad += '---------------------------------------------';
# 		alert(cad);
# 		return false;
# 	}else{
# 			return true;
# 		}
#
# }
#
# function emptyCarro(_accion){
#
# 	if(!confirm('Seguro desea vaciar el carro de compras?'))
# 		return false;
#
# 	jQuery.get("inc-carro.php", { actions: _accion},
# 	function(data){
# 		document.getElementById("contenido-carro").innerHTML = data;
# 	});
#
# 	jQuery.get("inc-ver_carro.php",
# 	function(data){
# 		document.getElementById("ver_carro").innerHTML = data;
# 	});
#
#
# 	return false;
# }
#
# </script>
# <link href="../JVS1/css/jquery-ui-1.8.4.custom.css" rel="stylesheet" type="text/css"/>
# <script src="../JVS1/js/jquery-1.4.2.min.js" type="text/javascript"></script>
# <script src="../JVS1/js/jquery-ui-1.8.4.custom.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# $(function(){
# 	$('#buscar_producto').autocomplete({
# 	   source : '../ajax.php',
# 	   minLength: 3,
# 	   select : function(event, ui){
# 		  location.href = 'drogueria-mg-productos.php?buscar_producto='+ui.item.value;
# 	   }
# 	});
# });
# </script>
# <div id="top">
# <a class="logo" href="index.php"><img alt="Droguería MG" height="150" src="graf/logo-drogueria-mg.png" width="255"/></a>
# <a class="icono-inicio" href="index.php" title="Ir al inicio">Inicio</a>
# <a class="icono-mail" href="drogueria-mg-contacto.php" title="Realizar una consulta">Contacto</a>
# <form action="login.php" id="form1" method="post" name="form1">
# <label>
# <input class="form-login-usr" id="usr" name="usr" onblur="restauracampo();" onclick="borracampo();" type="text" value="Usuario"/>
# </label>
# <label>
# <input class="form-login-pass" id="pass" name="pass" onblur="restauracampopass();" onclick="borracampopass();" type="password" value="Usuario"/>
# </label>
# <input id="button" name="button" type="submit" value="Ingresar"/>
# <input id="send" name="send" type="hidden" value="1"/>
# </form>
# <p class="link-registrarse">Si usted no es usuario debe <a href="drogueria-mg-registro.php">Registrarse</a></p>
# <p class="link-olvido-pass"><a href="popup-recuperar.php" rel="shadowbox;width=390;height=230">¿Olvidó su contraseña?</a></p>
# <label class="show-menu" for="show-menu">Menú</label>
# <input id="show-menu" role="button" type="checkbox"/>
# <ul class="menu" id="menu">
# <li><a href="drogueria-mg-productos.php">Catálogo de productos</a></li>
# <li><a href="drogueria-mg-productos-ofertas.php">Ofertas</a></li>
# <li><a href="drogueria-mg-distribuidores.php">Donde comprar nuestros productos</a></li>
# <li><a href="drogueria-mg-carro.php">Ver carro de pedidos</a></li>
# </ul>
# <div id="ver_carro">
# <p class="prods-en-carro">(No hay productos en su carro)</p>
# </div>
# <script language="javascript">
#
# var fecha=new Date();
# var diames=fecha.getDate();
# var diasemana=fecha.getDay();
# var mes=fecha.getMonth() +1 ;
# var ano=fecha.getFullYear();
#
# var textosemana = new Array (7);
#   textosemana[0]="Domingo";
#   textosemana[1]="Lunes";
#   textosemana[2]="Martes";
#   textosemana[3]="Miércoles";
#   textosemana[4]="Jueves";
#   textosemana[5]="Viernes";
#   textosemana[6]="Sábado";
#
# var textomes = new Array (12);
#   textomes[1]="Enero";
#   textomes[2]="Febrero";
#   textomes[3]="Marzo";
#   textomes[4]="Abril";
#   textomes[5]="Mayo";
#   textomes[6]="Junio";
#   textomes[7]="Julio";
#   textomes[8]="Agosto";
#   textomes[9]="Septiembre";
#   textomes[10]="Octubre";
#   textomes[11]="Noviembre";
#   textomes[12]="Diciembre";
# </script>
# <div class="fecha" id="fechahora"><script language="javascript">document.write(textosemana[diasemana] + " " + diames + " de " + textomes[mes] + " de " + ano );</script></div>
# </div>
# <div id="contenedor">
# <div id="contenido2">
# <div id="principal">
# <h2>Lista de productos</h2>
# <h5>Resultados de búsqueda</h5>
# <ul class="listado-productos">
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_c0c7c76d30bd3dcaefc96f40275bdc0a" name="cc" type="text" value="1">
# </input></label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=c0c7c76d30bd3dcaefc96f40275bdc0a">ACEITE DE ALMENDRAS X 40CC TABLADA
#                        </a>
# <div class="iconos">
# <img alt="ACEITE DE ALMENDRAS X 40CC TABLADA" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475668215_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=c0c7c76d30bd3dcaefc96f40275bdc0a" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('c0c7c76d30bd3dcaefc96f40275bdc0a', document.getElementById('cc_c0c7c76d30bd3dcaefc96f40275bdc0a').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_a684eceee76fc522773286a895bc8436" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=a684eceee76fc522773286a895bc8436">ACEITE DE COCO "PURO" X 125 CC…
#                        </a>
# <div class="iconos">
# <img alt='ACEITE DE COCO "PURO" X 125 CC TABLADA' height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475527458_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=a684eceee76fc522773286a895bc8436" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('a684eceee76fc522773286a895bc8436', document.getElementById('cc_a684eceee76fc522773286a895bc8436').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_9f61408e3afb633e50cdf1b20de6f466" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=9f61408e3afb633e50cdf1b20de6f466">ACEITE DE COCO "PURO" X LT TABLADA
#                        </a>
# <div class="iconos">
# <img alt='ACEITE DE COCO "PURO" X LT TABLADA' height="27" src="graf/icono-stock-rojo.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1541605742_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=9f61408e3afb633e50cdf1b20de6f466" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('9f61408e3afb633e50cdf1b20de6f466', document.getElementById('cc_9f61408e3afb633e50cdf1b20de6f466').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_44f683a84163b3523afe57c2e008bc8c" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=44f683a84163b3523afe57c2e008bc8c">ACEITE DE RICINO X 30CC IBC
#                        </a>
# <div class="iconos">
# <img alt="ACEITE DE RICINO X 30CC IBC" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475671135_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=44f683a84163b3523afe57c2e008bc8c" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('44f683a84163b3523afe57c2e008bc8c', document.getElementById('cc_44f683a84163b3523afe57c2e008bc8c').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_1f0e3dad99908345f7439f8ffabdffc4" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=1f0e3dad99908345f7439f8ffabdffc4">ACEITE PARA CUTICULA (AF 04301)
#                        </a>
# <div class="iconos">
# <img alt="ACEITE PARA CUTICULA (AF 04301)" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1670008483_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=1f0e3dad99908345f7439f8ffabdffc4" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('1f0e3dad99908345f7439f8ffabdffc4', document.getElementById('cc_1f0e3dad99908345f7439f8ffabdffc4').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_7dd11ae2d5ed34925bdbdc9b01866349" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=7dd11ae2d5ed34925bdbdc9b01866349">ACEITE PARA CUTICULA (AF 04301) *oferta x…
#                        </a>
# <div class="iconos">
# <img alt="ACEITE PARA CUTICULA (AF 04301) *oferta x 12u.*" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <img alt="Producto en Promoción" height="27" src="graf/icono-destacados.png" title="Producto en Promoción" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1670008499_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=7dd11ae2d5ed34925bdbdc9b01866349" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('7dd11ae2d5ed34925bdbdc9b01866349', document.getElementById('cc_7dd11ae2d5ed34925bdbdc9b01866349').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc
 100CC
#                        </a>
# <div class="iconos">
# <img alt="AGUA OXIGENADA  40 VOL X 100CC " height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1668786459_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=1a344877f11195aaf947ccfe48ee9c89" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('1a344877f11195aaf947ccfe48ee9c89', document.getElementById('cc_1a344877f11195aaf947ccfe48ee9c89').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_a97da629b098b75c294dffdc3e463904" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=a97da629b098b75c294dffdc3e463904">AGUA OXIGENADA  50 VOL X 100CC
#                        </a>
# <div class="iconos">
# <img alt="AGUA OXIGENADA  50 VOL X 100CC" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1511364101_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=a97da629b098b75c294dffdc3e463904" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('a97da629b098b75c294dffdc3e463904', document.getElementById('cc_a97da629b098b75c294dffdc3e463904').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_07e1cd7dca89a1678042477183b7ac3f" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=07e1cd7dca89a1678042477183b7ac3f">AGUJAS DESCARTABLES 13/3  (30 G 1/2)X 100U…
#                        </a>
# <div class="iconos">
# <img alt="AGUJAS DESCARTABLES 13/3  (30 G 1/2)X 100U BREMEN" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475771420_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=07e1cd7dca89a1678042477183b7ac3f" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('07e1cd7dca89a1678042477183b7ac3f', document.getElementById('cc_07e1cd7dca89a1678042477183b7ac3f').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_4c56ff4ce4aaf9573aa5dff913df997a" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=4c56ff4ce4aaf9573aa5dff913df997a">AGUJAS DESCARTABLES 13/4 (27G 1/2) X 100U…
#                        </a>
# <div class="iconos">
# <img alt="AGUJAS DESCARTABLES 13/4 (27G 1/2) X 100U CORON/BREM" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475771464_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=4c56ff4ce4aaf9573aa5dff913df997a" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('4c56ff4ce4aaf9573aa5dff913df997a', document.getElementById('cc_4c56ff4ce4aaf9573aa5dff913df997a').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_2835acf1b5aaa6ade0d10b4c977e912a" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=2835acf1b5aaa6ade0d10b4c977e912a">AGUJAS DESCARTABLES 16/5 (25 G 5/8) X 100U
#                        </a>
# <div class="iconos">
# ...
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('f0fcf351df4eb6786e9bb6fc4e2dee02', document.getElementById('cc_f0fcf351df4eb6786e9bb6fc4e2dee02').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_a87ff679a2f3e71d9181a67b7542122c" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=a87ff679a2f3e71d9181a67b7542122c">AGUJAS DESCARTABLES 50/12 (18GX2") X…
#                        </a>
# <div class="iconos">
# <img alt='AGUJAS DESCARTABLES 50/12 (18GX2") X 100 U. TROCCA' height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475772281_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=a87ff679a2f3e71d9181a67b7542122c" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('a87ff679a2f3e71d9181a67b7542122c', document.getElementById('cc_a87ff679a2f3e71d9181a67b7542122c').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_06cdc05791b8af29eed72084f39143c7" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=06cdc05791b8af29eed72084f39143c7">AGUJAS DESCARTABLES 50/12 (18GX2") X…
#                        </a>
# <div class="iconos">
# <img alt='AGUJAS DESCARTABLES 50/12 (18GX2") X 100 U. TROCCA *oferta | sin devolucion*' height="27" src="graf/icono-stock-rojo.png" width="27"/>
# <img alt="Producto en Promoción" height="27" src="graf/icono-destacados.png" title="Producto en Promoción" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1668784086_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=06cdc05791b8af29eed72084f39143c7" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('06cdc05791b8af29eed72084f39143c7', document.getElementById('cc_06cdc05791b8af29eed72084f39143c7').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_76dc611d6ebaafc66cc0879c71b5db5c" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=76dc611d6ebaafc66cc0879c71b5db5c">AGUJAS DESCARTABLES 50/8 (21 G 2) X 100U
#                        </a>
# <div class="iconos">
# <img alt="AGUJAS DESCARTABLES 50/8 (21 G 2) X 100U" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1475771628_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=76dc611d6ebaafc66cc0879c71b5db5c" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('76dc611d6ebaafc66cc0879c71b5db5c', document.getElementById('cc_76dc611d6ebaafc66cc0879c71b5db5c').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_cd5099c73f75235d60ec0e90c4a092aa" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=cd5099c73f75235d60ec0e90c4a092aa">ALCANFOR DEER 12 BLISTER X 4 TABLETAS *oferta*
#                        </a>
# <div class="iconos">
# <img alt="ALCANFOR DEER 12 BLISTER X 4 TABLETAS *oferta*" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <img alt="Producto en Promoción" height="27" src="graf/icono-destacados.png" title="Producto en Promoción" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1588254318_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=cd5099c73f75235d60ec0e90c4a092aa" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('cd5099c73f75235d60ec0e90c4a092aa', document.getElementById('cc_cd5099c73f75235d60ec0e90c4a092aa').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_f740c8d9c193f16d8a07d3a8a751d13f" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=f740c8d9c193f16d8a07d3a8a751d13f">ALCANFOR DEER X 128 TABLETAS *oferta*
#                        </a>
# <div class="iconos">
# <img alt="ALCANFOR DEER X 128 TABLETAS *oferta*" height="27" src="graf/icono-stock-amarillo.png" width="27"/>
# <img alt="Producto en Promoción" height="27" src="graf/icono-destacados.png" title="Producto en Promoción" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1588254340_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=f740c8d9c193f16d8a07d3a8a751d13f" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('f740c8d9c193f16d8a07d3a8a751d13f', document.getElementById('cc_f740c8d9c193f16d8a07d3a8a751d13f').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_0f28b5d49b3020afeecd95b4009adf4c" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=0f28b5d49b3020afeecd95b4009adf4c">ALCOHOL BORICADO X 100CC SANADROG
#                        </a>
# <div class="iconos">
# <img alt="ALCOHOL BORICADO X 100CC SANADROG" height="27" src="graf/icono-stock-verde.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1668520723_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=0f28b5d49b3020afeecd95b4009adf4c" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('0f28b5d49b3020afeecd95b4009adf4c', document.getElementById('cc_0f28b5d49b3020afeecd95b4009adf4c').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# <li>
# <label>
# <input class="input-cantidad-listados" id="cc_fcd11da01e886bc1be35b19f4d974f4e" name="cc" type="text" value="1"/>
# </label>
# <a class="copete" href="drogueria-mg-productos-detalle.php?id=fcd11da01e886bc1be35b19f4d974f4e">ALCOHOL DISMAR 10U. X 250CC
#                        </a>
# <div class="iconos">
# <img alt="ALCOHOL DISMAR 10U. X 250CC" height="27" src="graf/icono-stock-amarillo.png" width="27"/>
# <a class="preview" href="graf/imagenes/IMG_d41d8cd98f00b204e9800998ecf8427e_1668451589_GR.jpg" rel="shadowbox">
# <img alt="ver foto" height="27" src="graf/icono-fotos.png" width="27"/>
# </a>
# <a href="#"></a>
# <a href="popup-comentarios.php?id=fcd11da01e886bc1be35b19f4d974f4e" rel="shadowbox;width=600;height=430">
# <img alt="Agregar comentarios" height="27" src="graf/icono-notas.png" title="Agregar comentarios" width="27"/>
# </a>
# <a href="#" onclick="accionCarro('fcd11da01e886bc1be35b19f4d974f4e', document.getElementById('cc_fcd11da01e886bc1be35b19f4d974f4e').value ,'', 'add');return false;">
# <img alt="agregar al carro" height="27" src="graf/icono-carro-color.png" title="agregar al carro" width="27"/></a>
# </div>
# </li>
# </ul>
">43</a> <a href="/drogueria-mg-productos.php?p=44&amp;buscar_producto=">44</a> <a href="/drogueria-mg-productos.php?p=45&amp;buscar_producto=">45</a> <a href="/drogueria-mg-productos.php?p=46&amp;buscar_producto=">46</a> <a href="/drogueria-mg-productos.php?p=47&amp;buscar_producto=">47</a> <a href="/drogueria-mg-productos.php?p=48&amp;buscar_producto=">48</a> <a href="/drogueria-mg-productos.php?p=49&amp;buscar_producto=">49</a> <a href="/drogueria-mg-productos.php?p=50&amp;buscar_producto=">50</a> <a href="/drogueria-mg-productos.php?p=51&amp;buscar_producto=">51</a> <a href="/drogueria-mg-productos.php?p=52&amp;buscar_producto=">52</a> <a href="/drogueria-mg-productos.php?p=53&amp;buscar_producto=">53</a> <a href="/drogueria-mg-productos.php?p=54&amp;buscar_producto=">54</a> <a href="/drogueria-mg-productos.php?p=55&amp;buscar_producto=">55</a> <a href="/drogueria-mg-productos.php?p=56&amp;buscar_producto=">56</a> <a href="/drogueria-mg-productos.php?p=57&amp;buscar ...
# <div id="columna">
# <form action="drogueria-mg-productos.php" class="buscador esconde-resp" id="form2" method="get" name="form2">
# <div id="busqueda">
# <label>
# <input class="buscador-input" id="buscar_producto" name="buscar_producto" type="text" value=""/>
# </label>
# </div>
# <!--<div id="resultados">
#
#         </div>-->
# <label>
# <input class="buscador-boton" id="buscar" name="buscar" title="Buscar" type="submit" value=""/>
# </label>
# </form>
# <div id="contenido-carro">
# <form action="" class="form-carro-columna" id="form1" method="post" name="form1">
# <div class="modulo-carro">
# <h1 class="tits-carro-columa">Estado del Carro</h1>
# <span class="carro-columna">
# <p class="textos-margen">No hay productos en su carro.</p>
# </span></div>
# </form> </div>
# <a href="drogueria-mg-contacto.php"><img alt="Realizar una consulta" height="88" src="graf/banner-contacto-columna.jpg" width="260"/></a>
# </div> <div id="aviso">
# <div class="muestra-resp" id="columna">
# <form action="drogueria-mg-productos.php" class="buscador2" id="form2" method="get" name="form2">
# <div id="busqueda">
# <label>
# <input class="buscador-input2" id="buscar_producto" name="buscar_producto" type="text" value=""/>
# </label>
# </div>
# <!--<div id="resultados">
#
#     </div>-->
# <label>
# <input class="buscador-boton2" id="buscar" name="buscar" title="Buscar" type="submit" value=""/>
# </label>
# </form> </div>
# </div>
# </div>
# </div>
# <div id="pie">
# <!--<img class="gaspi" src="graf/logo-gaspi.png" alt="Distribuidor exclusivo l&iacute;nea de productos Gaspi" width="168" height="88" />
#     <img class="logos-pie" src="graf/logos-slide-1.gif" width="650" height="62" />-->
# <p class="domicilio">Málaga 1610 Bº Crisol / Tel. 0351 456 3563 y rotativas /
#     <script type="text/javascript">
#         <!--
#         var casilla = 'info';
#         var arroba = '@';
#         var dominio = location.host.replace('www.','');
#         var correo = casilla+arroba+dominio;
#         document.write(' <a href="mailto:'+correo+'?Subject=Consulta desde el sitio web">'+correo+'</a>');
#         //-->
#     </script>
# </p>
# <p class="copright">© Copyrights 2011 - Todos los derechos reservados</p>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1604920-90', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-21626352-7']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# </body>
